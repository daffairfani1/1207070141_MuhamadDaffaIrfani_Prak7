# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray 
import numpy as np

# %%
citra1 = cv2.imread('/content/drives/MyDrive/Colab Notebooks/anya.jpg.tif')
citra2 = cv2.imread('/content/drives/MyDrive/Colab Notebooks/pentol.jpg.tif')

print('Shape citra 1 : ', citra1.shape)
print('Shape citra 2 : ', citra2.shape)

fig, axes = plt.subplots(1, 2, figsize=(10, 10))
ax = axes.ravel()

ax[0].imshow(citra1, cmap = 'gray')
ax[0].set_title("Citra 1")
ax[1].imshow(citra2, cmap = 'gray')
ax[1].set_title("Citra 2")
# Out:
# Shape citra 1 :  (731, 745, 3)
# Shape citra 2 :  (622, 350, 3)
# Text(0.5, 1.0, 'Citra 2')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray 
import numpy as np

copyCitra1 = citra1.copy().astype(float)
copyCitra2 = citra2.copy().astype(float)

m1,n1 = copyCitra1.shape
output1 = np.empty([m1,n1])

m2,n2= copyCitra2.shape
output2 = np.empty([m2,n2])
print('Shape copy citra 1 : ', copyCitra1.shape)
print('Shape output citra 1 : ', output1.shape)

print('m1 : ',m1)
print('n1 : ',n1)
print()

print('Shape copy citra 2 : ', copyCitra2.shape)
print('Shape output citra 3 : ', output2.shape)
print('m2 : ',m2)
print('n2 : ',n2)
print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b8aa42a076c5> in <cell line: 12>()
#      10 copyCitra2 = citra2.copy().astype(float)
#      11
# ---> 12 m1,n1 = copyCitra1.shape
#      13 output1 = np.empty([m1,n1])
#      14
#
# ValueError: too many values to unpack (expected 2)

# %%
for baris in range(0, m1-1):
    for kolom in range(0, n1-1):
        a1 = baris
        b1 = kolom
        jumlah = copyCitra1[a1-1, b1-1] + copyCitra1[a1-1, b1] + copyCitra1[a1-1, b1-1] + \
                 copyCitra1[a1, b1-1] + copyCitra1[a1, b1] + copyCitra1[a1, b1+1] + \
                 copyCitra1[a1+1, b1-1] + copyCitra1[a1+1, b1] + copyCitra1[a1+1, b1+1];  
        output1[a1, b1] = (1/9 * jumlah)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6bbcf0536ec2> in <cell line: 1>()
# ----> 1 for baris in range(0, m1-1):
#       2     for kolom in range(0, n1-1):
#       3         a1 = baris
#       4         b1 = kolom
#       5         jumlah = copyCitra1[a1-1, b1-1] + copyCitra1[a1-1, b1] + copyCitra1[a1-1, b1-1] + \
#
# NameError: name 'm1' is not defined
